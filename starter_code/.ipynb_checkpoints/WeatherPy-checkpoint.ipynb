# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "?q=" + city + "&appid=" + weather_api_key
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    try:
    # Run an API request for each of the cities
        print(city_url)
        response = requests.get(city_url).json()
        print(response)
        break;
    except:
        print("City not found. Skipping...")
        pass
    
    
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-louis
# https://api.openweathermap.org/data/2.5/weather?q=saint-louis&appid=f0e84735defe5c0d6e6d12c5e242739b
# {'coord': {'lon': -15, 'lat': 16.3333}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 300.95, 'feels_like': 302.31, 'temp_min': 300.95, 'temp_max': 300.95, 'pressure': 1011, 'humidity': 60, 'sea_level': 1011, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 3.96, 'deg': 302, 'gust': 5.67}, 'clouds': {'all': 37}, 'dt': 1697173284, 'sys': {'type': 1, 'id': 2427, 'country': 'SN', 'sunrise': 1697179903, 'sunset': 1697222437}, 'timezone': 0, 'id': 2246451, 'name': 'Saint-Louis', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count = set_count + 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "?q=" + city + "&appid=" + weather_api_key
    #print(city_url)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count = record_count + 1

    # Run an API request for each of the cities
    try:
        response = requests.get(city_url).json()
        
        # Parse the JSON and retrieve data
        #city_weather = response['weather']

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response['coord']['lat']
        
        city_lng = response['coord']['lon']
        
        city_max_temp = response['main']['temp_max']
        
        city_humidity = response['main']['humidity']
        
        city_clouds = response['clouds']['all']
        
        city_wind = response['wind']['speed']
        
        city_country = response['sys']['country']
        
        city_date = response['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        
        #print(city_data)

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-louis
# Processing Record 2 of Set 1 | afaahiti
# Processing Record 3 of Set 1 | kapit
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | inari
# Processing Record 7 of Set 1 | lihue
# Processing Record 8 of Set 1 | waitangi
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | udachny
# Processing Record 11 of Set 1 | badger
# Processing Record 12 of Set 1 | colonia
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | monteagudo
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | kapa'a
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | puerto natales
# Processing Record 20 of Set 1 | edinburgh of the seven seas
# Processing Record 21 of Set 1 | enewetak
# Processing Record 22 of Set 1 | la passe
# Processing Record 23 of Set 1 | zholymbet
# Processing Record 24 of Set 1 | aasiaat
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | invercargill
# Processing Record 27 of Set 1 | haiku-pauwela
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | fort st. john
# Processing Record 30 of Set 1 | hafar al-batin
# Processing Record 31 of Set 1 | newman
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | chibougamau
# Processing Record 34 of Set 1 | aripuana
# Processing Record 35 of Set 1 | olonkinbyen
# Processing Record 36 of Set 1 | hilton
# Processing Record 37 of Set 1 | inhambane
# Processing Record 38 of Set 1 | kuta
# Processing Record 39 of Set 1 | ryazhsk
# Processing Record 40 of Set 1 | san patricio
# Processing Record 41 of Set 1 | saipan
# Processing Record 42 of Set 1 | kuvandyk
# Processing Record 43 of Set 1 | praia da vitoria
# Processing Record 44 of Set 1 | miches
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | port saint john's
# Processing Record 47 of Set 1 | camabatela
# Processing Record 48 of Set 1 | iskateley
# Processing Record 49 of Set 1 | grytviken
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 0 of Set 2 | tamanrasset
# Processing Record 1 of Set 2 | emerald
# Processing Record 2 of Set 2 | adamstown
# Processing Record 3 of Set 2 | vila velha
# Processing Record 4 of Set 2 | boali
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | santa rosalia
# Processing Record 7 of Set 2 | tobelo
# Processing Record 8 of Set 2 | papatowai
# Processing Record 9 of Set 2 | bich'vinta
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | whitehorse
# Processing Record 13 of Set 2 | chonchi
# Processing Record 14 of Set 2 | banda aceh
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | north bend
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | puerto baquerizo moreno
# Processing Record 19 of Set 2 | blackmans bay
# Processing Record 20 of Set 2 | siyabuswa
# Processing Record 21 of Set 2 | aykhal
# Processing Record 22 of Set 2 | vikhorevka
# Processing Record 23 of Set 2 | chegdomyn
# Processing Record 24 of Set 2 | freetown
# Processing Record 25 of Set 2 | devinuwara
# City not found. Skipping...
# Processing Record 26 of Set 2 | jumla
# Processing Record 27 of Set 2 | sangre grande
# Processing Record 28 of Set 2 | wolbrom
# Processing Record 29 of Set 2 | kavaratti
# Processing Record 30 of Set 2 | ar rahad
# Processing Record 31 of Set 2 | flying fish cove
# Processing Record 32 of Set 2 | nogliki
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | dudinka
# Processing Record 35 of Set 2 | kolwezi
# Processing Record 36 of Set 2 | tazovsky
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 39 of Set 2 | cueibet
# City not found. Skipping...
# Processing Record 40 of Set 2 | quelimane
# Processing Record 41 of Set 2 | ulladulla
# Processing Record 42 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 43 of Set 2 | saeby
# Processing Record 44 of Set 2 | ballina
# Processing Record 45 of Set 2 | mount isa
# Processing Record 46 of Set 2 | kandalaksha
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | motygino
# Processing Record 49 of Set 2 | chalus
# Processing Record 0 of Set 3 | dunedin
# Processing Record 1 of Set 3 | ust-nera
# Processing Record 2 of Set 3 | meads
# Processing Record 3 of Set 3 | prince rupert
# Processing Record 4 of Set 3 | hamilton
# Processing Record 5 of Set 3 | nova sintra
# Processing Record 6 of Set 3 | askoy
# Processing Record 7 of Set 3 | margaret river
# Processing Record 8 of Set 3 | hasaki
# Processing Record 9 of Set 3 | san luis de la loma
# Processing Record 10 of Set 3 | sirsa
# Processing Record 11 of Set 3 | dolisie
# Processing Record 12 of Set 3 | petropavlovka
# Processing Record 13 of Set 3 | nuku'alofa
# Processing Record 14 of Set 3 | happy valley-goose bay
# Processing Record 15 of Set 3 | greenland
# Processing Record 16 of Set 3 | susuman
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | lebu
# Processing Record 19 of Set 3 | ponta delgada
# Processing Record 20 of Set 3 | antsiranana
# Processing Record 21 of Set 3 | fale old settlement
# Processing Record 22 of Set 3 | longyearbyen
# Processing Record 23 of Set 3 | cabo san lucas
# Processing Record 24 of Set 3 | farah
# Processing Record 25 of Set 3 | camocim
# Processing Record 26 of Set 3 | katsuura
# Processing Record 27 of Set 3 | farafangana
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | nosy varika
# Processing Record 30 of Set 3 | markaz-e hukumat-e darweshan
# Processing Record 31 of Set 3 | stanley
# Processing Record 32 of Set 3 | ancud
# Processing Record 33 of Set 3 | bilibino
# Processing Record 34 of Set 3 | peniche
# Processing Record 35 of Set 3 | sinabang
# Processing Record 36 of Set 3 | inarajan village
# Processing Record 37 of Set 3 | rolla
# Processing Record 38 of Set 3 | san jose village
# City not found. Skipping...
# Processing Record 39 of Set 3 | atafu village
# Processing Record 40 of Set 3 | northam
# Processing Record 41 of Set 3 | uruzgan
# Processing Record 42 of Set 3 | santa elena de uairen
# Processing Record 43 of Set 3 | talnakh
# Processing Record 44 of Set 3 | loreto
# Processing Record 45 of Set 3 | glazov
# Processing Record 46 of Set 3 | mariental
# Processing Record 47 of Set 3 | port mathurin
# Processing Record 48 of Set 3 | parambu
# Processing Record 49 of Set 3 | benguela
# Processing Record 0 of Set 4 | saguenay
# Processing Record 1 of Set 4 | quellon
# Processing Record 2 of Set 4 | xining
# Processing Record 3 of Set 4 | mazagao
# Processing Record 4 of Set 4 | uaboe
# City not found. Skipping...
# Processing Record 5 of Set 4 | tadine
# Processing Record 6 of Set 4 | zheleznogorsk-ilimskiy
# Processing Record 7 of Set 4 | menongue
# Processing Record 8 of Set 4 | silver city
# Processing Record 9 of Set 4 | nadi
# Processing Record 10 of Set 4 | greymouth
# Processing Record 11 of Set 4 | kontcha
# Processing Record 12 of Set 4 | ghadamis
# Processing Record 13 of Set 4 | baker city
# Processing Record 14 of Set 4 | klyuchi
# Processing Record 15 of Set 4 | kishapu
# Processing Record 16 of Set 4 | phimai
# Processing Record 17 of Set 4 | lompoc
# Processing Record 18 of Set 4 | haining
# Processing Record 19 of Set 4 | sydney
# Processing Record 20 of Set 4 | moranbah
# Processing Record 21 of Set 4 | mhamid
# Processing Record 22 of Set 4 | isafjordur
# Processing Record 23 of Set 4 | zabol
# Processing Record 24 of Set 4 | gazli
# Processing Record 25 of Set 4 | sitka
# Processing Record 26 of Set 4 | baotou
# Processing Record 27 of Set 4 | haiphong
# Processing Record 28 of Set 4 | uturoa
# Processing Record 29 of Set 4 | motala
# Processing Record 30 of Set 4 | waingapu
# Processing Record 31 of Set 4 | vorkuta
# Processing Record 32 of Set 4 | ves'yegonsk
# Processing Record 33 of Set 4 | west island
# Processing Record 34 of Set 4 | mejit
# Processing Record 35 of Set 4 | tomatlan
# Processing Record 36 of Set 4 | vernon
# Processing Record 37 of Set 4 | brisas de zicatela
# Processing Record 38 of Set 4 | alofi
# Processing Record 39 of Set 4 | niamey
# Processing Record 40 of Set 4 | fort bragg
# Processing Record 41 of Set 4 | kalisz
# Processing Record 42 of Set 4 | utrik
# Processing Record 43 of Set 4 | yuncheng
# Processing Record 44 of Set 4 | hawaiian paradise park
# Processing Record 45 of Set 4 | eyl
# Processing Record 46 of Set 4 | vorgashor
# Processing Record 47 of Set 4 | luderitz
# Processing Record 48 of Set 4 | hoi an
# Processing Record 49 of Set 4 | uruacu
# Processing Record 0 of Set 5 | college
# Processing Record 1 of Set 5 | nuuk
# Processing Record 2 of Set 5 | pimenta bueno
# Processing Record 3 of Set 5 | wakkanai
# Processing Record 4 of Set 5 | eastbourne
# Processing Record 5 of Set 5 | sibut
# Processing Record 6 of Set 5 | boonville
# Processing Record 7 of Set 5 | kitami
# Processing Record 8 of Set 5 | port lincoln
# Processing Record 9 of Set 5 | formosa
# Processing Record 10 of Set 5 | taroudant
# Processing Record 11 of Set 5 | ejura
# Processing Record 12 of Set 5 | tura
# Processing Record 13 of Set 5 | kaa-khem
# Processing Record 14 of Set 5 | crateus
# Processing Record 15 of Set 5 | urengoy
# Processing Record 16 of Set 5 | keflavik
# Processing Record 17 of Set 5 | ayame
# Processing Record 18 of Set 5 | talodi
# Processing Record 19 of Set 5 | tari
# Processing Record 20 of Set 5 | kayangel
# Processing Record 21 of Set 5 | jabat
# Processing Record 22 of Set 5 | le port
# Processing Record 23 of Set 5 | coquimbo
# Processing Record 24 of Set 5 | porto novo
# Processing Record 25 of Set 5 | makinsk
# Processing Record 26 of Set 5 | ts'q'alt'ubo
# Processing Record 27 of Set 5 | anadyr
# Processing Record 28 of Set 5 | madimba
# Processing Record 29 of Set 5 | kodiak
# Processing Record 30 of Set 5 | avarua
# Processing Record 31 of Set 5 | touros
# Processing Record 32 of Set 5 | wailua homesteads
# Processing Record 33 of Set 5 | tikapur
# Processing Record 34 of Set 5 | portland
# Processing Record 35 of Set 5 | tongchuanshi
# Processing Record 36 of Set 5 | carutapera
# Processing Record 37 of Set 5 | hoemul-li
# Processing Record 38 of Set 5 | kayenta
# Processing Record 39 of Set 5 | puerto deseado
# Processing Record 40 of Set 5 | uliastay
# Processing Record 41 of Set 5 | manggar
# Processing Record 42 of Set 5 | tutoia
# Processing Record 43 of Set 5 | kataragama
# City not found. Skipping...
# Processing Record 44 of Set 5 | horsham
# Processing Record 45 of Set 5 | iquique
# Processing Record 46 of Set 5 | okha
# Processing Record 47 of Set 5 | ierapetra
# Processing Record 48 of Set 5 | tindouf
# Processing Record 49 of Set 5 | port-gentil
# Processing Record 0 of Set 6 | salinopolis
# Processing Record 1 of Set 6 | darnah
# Processing Record 2 of Set 6 | vila franca do campo
# Processing Record 3 of Set 6 | howard springs
# Processing Record 4 of Set 6 | xam nua
# Processing Record 5 of Set 6 | palmer
# Processing Record 6 of Set 6 | holualoa
# Processing Record 7 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 8 of Set 6 | port hedland
# Processing Record 9 of Set 6 | papao
# Processing Record 10 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 11 of Set 6 | fabens
# Processing Record 12 of Set 6 | carbondale
# Processing Record 13 of Set 6 | dadonghai
# City not found. Skipping...
# Processing Record 14 of Set 6 | guichon
# Processing Record 15 of Set 6 | selfoss
# Processing Record 16 of Set 6 | yuzhno-kurilsk
# Processing Record 17 of Set 6 | emmett
# Processing Record 18 of Set 6 | tomakivka
# Processing Record 19 of Set 6 | bandarbeyla
# Processing Record 20 of Set 6 | belyy yar
# Processing Record 21 of Set 6 | richards bay
# Processing Record 22 of Set 6 | peno
# Processing Record 23 of Set 6 | mili
# Processing Record 24 of Set 6 | kailua-kona
# Processing Record 25 of Set 6 | presidencia de la plaza
# Processing Record 26 of Set 6 | sisimiut
# Processing Record 27 of Set 6 | kovylkino
# Processing Record 28 of Set 6 | iranshahr
# Processing Record 29 of Set 6 | milas
# Processing Record 30 of Set 6 | ocos
# Processing Record 31 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 32 of Set 6 | egilsstadir
# Processing Record 33 of Set 6 | bubaque
# Processing Record 34 of Set 6 | marsh harbour
# Processing Record 35 of Set 6 | hadibu
# Processing Record 36 of Set 6 | pathein
# Processing Record 37 of Set 6 | guerrero negro
# Processing Record 38 of Set 6 | yelizovo
# Processing Record 39 of Set 6 | ambovombe
# Processing Record 40 of Set 6 | karratha
# Processing Record 41 of Set 6 | shorapur
# Processing Record 42 of Set 6 | tofol
# Processing Record 43 of Set 6 | little cayman
# City not found. Skipping...
# Processing Record 44 of Set 6 | ash shafa
# City not found. Skipping...
# Processing Record 45 of Set 6 | east london
# Processing Record 46 of Set 6 | north branch
# Processing Record 47 of Set 6 | ed damer
# Processing Record 48 of Set 6 | san rafael del yuma
# Processing Record 49 of Set 6 | raja
# Processing Record 0 of Set 7 | eldorado
# Processing Record 1 of Set 7 | ola
# Processing Record 2 of Set 7 | santa rosa
# Processing Record 3 of Set 7 | masterton
# Processing Record 4 of Set 7 | nagqu
# Processing Record 5 of Set 7 | beidao
# Processing Record 6 of Set 7 | huainan
# Processing Record 7 of Set 7 | ta`u
# Processing Record 8 of Set 7 | koryazhma
# Processing Record 9 of Set 7 | alice springs
# Processing Record 10 of Set 7 | manali
# Processing Record 11 of Set 7 | weno
# Processing Record 12 of Set 7 | mahibadhoo
# Processing Record 13 of Set 7 | talcahuano
# Processing Record 14 of Set 7 | tsiombe
# Processing Record 15 of Set 7 | geraldton
# Processing Record 16 of Set 7 | port elizabeth
# Processing Record 17 of Set 7 | cotonou
# Processing Record 18 of Set 7 | polyarnyy
# Processing Record 19 of Set 7 | puerto carreno
# Processing Record 20 of Set 7 | kyzyl
# Processing Record 21 of Set 7 | malvan
# Processing Record 22 of Set 7 | bamboo flat
# Processing Record 23 of Set 7 | kharkhorin
# Processing Record 24 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 25 of Set 7 | rio grande
# Processing Record 26 of Set 7 | san antonio de pale
# Processing Record 27 of Set 7 | constantia
# Processing Record 28 of Set 7 | vilyuchinsk
# Processing Record 29 of Set 7 | beloyarskiy
# Processing Record 30 of Set 7 | sicuani
# Processing Record 31 of Set 7 | basco
# Processing Record 32 of Set 7 | st. john's
# Processing Record 33 of Set 7 | san andres
# Processing Record 34 of Set 7 | watsa
# Processing Record 35 of Set 7 | dawesville
# Processing Record 36 of Set 7 | mermoz boabab
# Processing Record 37 of Set 7 | canutama
# Processing Record 38 of Set 7 | avanigadda
# Processing Record 39 of Set 7 | yaren
# Processing Record 40 of Set 7 | savanna-la-mar
# Processing Record 41 of Set 7 | la union
# Processing Record 42 of Set 7 | hiratacho
# Processing Record 43 of Set 7 | elverum
# Processing Record 44 of Set 7 | kapuskasing
# Processing Record 45 of Set 7 | nova vicosa
# Processing Record 46 of Set 7 | waddan
# Processing Record 47 of Set 7 | viedma
# Processing Record 48 of Set 7 | dholka
# Processing Record 49 of Set 7 | ijuw
# City not found. Skipping...
# Processing Record 0 of Set 8 | tan-tan
# Processing Record 1 of Set 8 | kandiari
# Processing Record 2 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 3 of Set 8 | limassol
# Processing Record 4 of Set 8 | vanimo
# Processing Record 5 of Set 8 | george town
# Processing Record 6 of Set 8 | margate
# Processing Record 7 of Set 8 | vadso
# Processing Record 8 of Set 8 | kulhudhuffushi
# Processing Record 9 of Set 8 | palangkaraya
# Processing Record 10 of Set 8 | twon-brass
# Processing Record 11 of Set 8 | we
# City not found. Skipping...
# Processing Record 12 of Set 8 | kavieng
# Processing Record 13 of Set 8 | mokopane
# Processing Record 14 of Set 8 | vakarai
# Processing Record 15 of Set 8 | la'ie
# Processing Record 16 of Set 8 | caninde
# Processing Record 17 of Set 8 | white oak
# Processing Record 18 of Set 8 | mont-tremblant
# Processing Record 19 of Set 8 | pacocha
# Processing Record 20 of Set 8 | kourou
# Processing Record 21 of Set 8 | bonthe
# Processing Record 22 of Set 8 | shalkar
# Processing Record 23 of Set 8 | kaliua
# Processing Record 24 of Set 8 | klaksvik
# Processing Record 25 of Set 8 | bataipora
# Processing Record 26 of Set 8 | bangaon
# Processing Record 27 of Set 8 | nainwa
# Processing Record 28 of Set 8 | bumba
# Processing Record 29 of Set 8 | carnarvon
# Processing Record 30 of Set 8 | aparri
# Processing Record 31 of Set 8 | saint-joseph
# Processing Record 32 of Set 8 | santona
# Processing Record 33 of Set 8 | ugoofaaru
# Processing Record 34 of Set 8 | kenora
# Processing Record 35 of Set 8 | gadzhiyevo
# Processing Record 36 of Set 8 | gorontalo
# Processing Record 37 of Set 8 | jalal-abad
# Processing Record 38 of Set 8 | campbell river
# Processing Record 39 of Set 8 | el daein
# City not found. Skipping...
# Processing Record 40 of Set 8 | navoloki
# Processing Record 41 of Set 8 | selkirk
# Processing Record 42 of Set 8 | new plymouth
# Processing Record 43 of Set 8 | qaqortoq
# Processing Record 44 of Set 8 | anibare
# City not found. Skipping...
# Processing Record 45 of Set 8 | kiama
# Processing Record 46 of Set 8 | gisborne
# Processing Record 47 of Set 8 | novyy urgal
# Processing Record 48 of Set 8 | broken hill
# Processing Record 49 of Set 8 | hastings
# Processing Record 0 of Set 9 | pierre
# Processing Record 1 of Set 9 | pangody
# Processing Record 2 of Set 9 | esposende
# Processing Record 3 of Set 9 | coahuayana de hidalgo
# Processing Record 4 of Set 9 | toga village
# City not found. Skipping...
# Processing Record 5 of Set 9 | sai buri
# Processing Record 6 of Set 9 | soio
# Processing Record 7 of Set 9 | siwa oasis
# Processing Record 8 of Set 9 | ilha de mocambique
# Processing Record 9 of Set 9 | niquelandia
# Processing Record 10 of Set 9 | garwolin
# Processing Record 11 of Set 9 | verkhnevilyuysk
# Processing Record 12 of Set 9 | quang ngai
# Processing Record 13 of Set 9 | zhanjiang
# Processing Record 14 of Set 9 | harper
# Processing Record 15 of Set 9 | kingston
# Processing Record 16 of Set 9 | pimentel
# Processing Record 17 of Set 9 | swakopmund
# Processing Record 18 of Set 9 | kupang
# Processing Record 19 of Set 9 | fort saskatchewan
# Processing Record 20 of Set 9 | cobram
# Processing Record 21 of Set 9 | pasargad
# City not found. Skipping...
# Processing Record 22 of Set 9 | tres palos
# Processing Record 23 of Set 9 | roma
# Processing Record 24 of Set 9 | ciudad lazaro cardenas
# Processing Record 25 of Set 9 | sao joao dos patos
# Processing Record 26 of Set 9 | nikolayevsk-on-amure
# Processing Record 27 of Set 9 | kearney
# Processing Record 28 of Set 9 | namtsy
# Processing Record 29 of Set 9 | ifon
# Processing Record 30 of Set 9 | ilebo
# Processing Record 31 of Set 9 | crane
# Processing Record 32 of Set 9 | torghay
# Processing Record 33 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 34 of Set 9 | curuzu cuatia
# Processing Record 35 of Set 9 | mana
# Processing Record 36 of Set 9 | rio verde
# Processing Record 37 of Set 9 | pampa
# Processing Record 38 of Set 9 | sola
# Processing Record 39 of Set 9 | abra pampa
# Processing Record 40 of Set 9 | fortuna
# Processing Record 41 of Set 9 | laojunmiao
# Processing Record 42 of Set 9 | uaua
# Processing Record 43 of Set 9 | mount pearl
# Processing Record 44 of Set 9 | mao
# Processing Record 45 of Set 9 | tralee
# Processing Record 46 of Set 9 | letlhakeng
# Processing Record 47 of Set 9 | yeppoon
# Processing Record 48 of Set 9 | santana
# Processing Record 49 of Set 9 | alexandria
# Processing Record 0 of Set 10 | svitlovods'k
# Processing Record 1 of Set 10 | eureka
# Processing Record 2 of Set 10 | muravlenko
# Processing Record 3 of Set 10 | pergamino
# Processing Record 4 of Set 10 | galle
# Processing Record 5 of Set 10 | maceio
# Processing Record 6 of Set 10 | orenburg
# Processing Record 7 of Set 10 | fernley
# Processing Record 8 of Set 10 | sur
# Processing Record 9 of Set 10 | yelovo
# Processing Record 10 of Set 10 | ebaye
# Processing Record 11 of Set 10 | brookings
# Processing Record 12 of Set 10 | gbarnga
# Processing Record 13 of Set 10 | nyurba
# Processing Record 14 of Set 10 | paradera
# City not found. Skipping...
# Processing Record 15 of Set 10 | mil'kovo
# Processing Record 16 of Set 10 | mata-utu
# Processing Record 17 of Set 10 | cabinda
# Processing Record 18 of Set 10 | kandyagash
# Processing Record 19 of Set 10 | bereeda
# Processing Record 20 of Set 10 | mount gambier
# Processing Record 21 of Set 10 | nabire
# Processing Record 22 of Set 10 | pindushi
# Processing Record 23 of Set 10 | sao joao da barra
# Processing Record 24 of Set 10 | midvagur
# Processing Record 25 of Set 10 | calabugao
# Processing Record 26 of Set 10 | chepo
# Processing Record 27 of Set 10 | aldan
# Processing Record 28 of Set 10 | wynyard
# Processing Record 29 of Set 10 | marechal candido rondon
# Processing Record 30 of Set 10 | petropavlovsk-kamchatsky
# Processing Record 31 of Set 10 | banjarmasin
# Processing Record 32 of Set 10 | hotan
# Processing Record 33 of Set 10 | sayat
# Processing Record 34 of Set 10 | smithers
# Processing Record 35 of Set 10 | jiaojiang
# Processing Record 36 of Set 10 | neftekamsk
# Processing Record 37 of Set 10 | westport
# Processing Record 38 of Set 10 | chiredzi
# Processing Record 39 of Set 10 | jiazi
# Processing Record 40 of Set 10 | baiti
# Processing Record 41 of Set 10 | korla
# Processing Record 42 of Set 10 | praia
# Processing Record 43 of Set 10 | tateyama
# Processing Record 44 of Set 10 | nema
# Processing Record 45 of Set 10 | gejiu
# Processing Record 46 of Set 10 | soe
# Processing Record 47 of Set 10 | nemuro
# Processing Record 48 of Set 10 | nar'yan-mar
# Processing Record 49 of Set 10 | ulanhot
# Processing Record 0 of Set 11 | mabaruma
# Processing Record 1 of Set 11 | gallivare
# City not found. Skipping...
# Processing Record 2 of Set 11 | thinadhoo
# Processing Record 3 of Set 11 | cachoeiro de itapemirim
# Processing Record 4 of Set 11 | bure
# Processing Record 5 of Set 11 | broome
# Processing Record 6 of Set 11 | botshabelo
# Processing Record 7 of Set 11 | brisas barra de suchiate
# Processing Record 8 of Set 11 | borisoglebskiy
# Processing Record 9 of Set 11 | jaicos
# Processing Record 10 of Set 11 | adh dhibiyah
# City not found. Skipping...
# Processing Record 11 of Set 11 | murzuq
# Processing Record 12 of Set 11 | el granada
# Processing Record 13 of Set 11 | saddle brooke
# City not found. Skipping...
# Processing Record 14 of Set 11 | antonio enes
# Processing Record 15 of Set 11 | forster
# Processing Record 16 of Set 11 | quepos
# Processing Record 17 of Set 11 | pisco
# Processing Record 18 of Set 11 | thurso
# Processing Record 19 of Set 11 | kurumkan
# Processing Record 20 of Set 11 | lumphat
# Processing Record 21 of Set 11 | starotitarovskaya
# Processing Record 22 of Set 11 | puerto aysen
# Processing Record 23 of Set 11 | fisterra
# Processing Record 24 of Set 11 | luorong
# Processing Record 25 of Set 11 | anqing
# Processing Record 26 of Set 11 | stettler
# Processing Record 27 of Set 11 | itaituba
# Processing Record 28 of Set 11 | zaragoza
# Processing Record 29 of Set 11 | kalaoa
# Processing Record 30 of Set 11 | nova olinda do norte
# Processing Record 31 of Set 11 | parun
# Processing Record 32 of Set 11 | prince george
# Processing Record 33 of Set 11 | walvis bay
# Processing Record 34 of Set 11 | anabar
# City not found. Skipping...
# Processing Record 35 of Set 11 | tolanaro
# Processing Record 36 of Set 11 | mankachar
# Processing Record 37 of Set 11 | katsuren-haebaru
# Processing Record 38 of Set 11 | hammerfest
# Processing Record 39 of Set 11 | saynshand
# Processing Record 40 of Set 11 | bandundu
# Processing Record 41 of Set 11 | el paujil
# Processing Record 42 of Set 11 | kerikeri
# Processing Record 43 of Set 11 | isla del bosque
# Processing Record 44 of Set 11 | sao joao evangelista
# Processing Record 45 of Set 11 | amarwara
# Processing Record 46 of Set 11 | san juan bautista
# Processing Record 47 of Set 11 | tres isletas
# Processing Record 48 of Set 11 | nantucket
# Processing Record 49 of Set 11 | queenstown
# Processing Record 0 of Set 12 | kargil
# Processing Record 1 of Set 12 | charters towers
# Processing Record 2 of Set 12 | mar del plata
# Processing Record 3 of Set 12 | meadow lakes
# Processing Record 4 of Set 12 | punta arenas
# Processing Record 5 of Set 12 | khandud
# Processing Record 6 of Set 12 | sao vicente
# Processing Record 7 of Set 12 | rawson
# Processing Record 8 of Set 12 | pacific grove
# Processing Record 9 of Set 12 | suva
# Processing Record 10 of Set 12 | temiskaming shores
# Processing Record 11 of Set 12 | keren
# Processing Record 12 of Set 12 | ghedi
# Processing Record 13 of Set 12 | dongkan
# Processing Record 14 of Set 12 | mahabe
# City not found. Skipping...
# Processing Record 15 of Set 12 | khovd
# Processing Record 16 of Set 12 | rio pardo de minas
# Processing Record 17 of Set 12 | tchintabaraden
# Processing Record 18 of Set 12 | mkushi
# Processing Record 19 of Set 12 | sinop
# Processing Record 20 of Set 12 | filandia
# Processing Record 21 of Set 12 | sile
# Processing Record 22 of Set 12 | shahpur
# Processing Record 23 of Set 12 | nova xavantina
# Processing Record 24 of Set 12 | kamaishi
# Processing Record 25 of Set 12 | sant'antioco
# Processing Record 26 of Set 12 | al burayqah
# Processing Record 27 of Set 12 | notodden
# Processing Record 28 of Set 12 | al jubayl
# Processing Record 29 of Set 12 | anshun
# Processing Record 30 of Set 12 | horta
# Processing Record 31 of Set 12 | labrador city
# Processing Record 32 of Set 12 | wanlaweyn
# Processing Record 33 of Set 12 | chicoana
# Processing Record 34 of Set 12 | kununurra
# Processing Record 35 of Set 12 | borgo
# Processing Record 36 of Set 12 | matoury
# Processing Record 37 of Set 12 | saint-pierre
# Processing Record 38 of Set 12 | kidal
# Processing Record 39 of Set 12 | kiunga
# Processing Record 40 of Set 12 | usinsk
# Processing Record 41 of Set 12 | sangin
# Processing Record 42 of Set 12 | jamul
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  saint-louis  16.3333  -15.0000    300.95        60          37        3.96
# 1     afaahiti -17.7500 -149.2833    299.08        81          12        7.01
# 2        kapit   2.0167  112.9333    305.36        57          80        1.14
# 3   georgetown   5.4112  100.3354    306.11        74          40        4.12
# 4       albany  42.6001  -73.9662    282.23        82          26        2.57
#
#   Country        Date
# 0      SN  1697173284
# 1      PF  1697173290
# 2      MY  1697173293
# 3      MY  1697173187
# 4      US  1697173110

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        saint-louis  16.3333  -15.0000    300.95        60          37
# 1           afaahiti -17.7500 -149.2833    299.08        81          12
# 2              kapit   2.0167  112.9333    305.36        57          80
# 3         georgetown   5.4112  100.3354    306.11        74          40
# 4             albany  42.6001  -73.9662    282.23        82          26
#
#          Wind Speed Country        Date
# City_ID
# 0              3.96      SN  1697173284
# 1              7.01      PF  1697173290
# 2              1.14      MY  1697173293
# 3              4.12      MY  1697173187
# 4              2.57      US  1697173110

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Max Temp"]
plt.scatter(x_axis, y_axis, marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.title("City Max Latitude vs. Temperature(2022-10-18)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Humidity"]
plt.scatter(x_axis, y_axis, marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Cloudiness"]
plt.scatter(x_axis, y_axis, marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Clodiness (%)")
plt.title("City Latitude vs. Clodiness (2022-10-18)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Wind Speed"]
plt.scatter(x_axis, y_axis, marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2022-10-18)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
